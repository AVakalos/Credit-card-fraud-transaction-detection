# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#print('Found and delete {} duplicate rows'.format(df.duplicated().sum()))
#df.drop_duplicates(ignore_index=True,inplace=True)

# %%
fig, ax = plt.subplots(5,6,figsize=(25,20))

for i,col in enumerate(df.columns.drop('Class')):
    sns.distplot(df[col],ax=ax[i//6][i%6])

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [raw]
# V1..V28 features are normalized since they come from PCA tranformation. No need to do something further without knowing more about the meanings of the features.
#
# Time and Amount need normalization before using them in a model.
#
# Time distribution is complicated instead of Amount distribution which shows that most of the transactions have small amounts. The mean is 88 USD.

# %%
# Normalize the features Amount and Time to mean 0 and unit variance 

to_norm_data = df[['Time','Amount']]

sc = StandardScaler()
sc.fit(to_norm_data)
df[['Time','Amount']] = sc.transform(to_norm_data)
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.050379e-14  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std    1.000002e+00  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min   -1.996583e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%   -8.552120e-01 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%   -2.131453e-01  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    9.372174e-01  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    1.642058e+00  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
sns.countplot(df['Class'])

# %%
vc = df['Class'].value_counts()
total = len(df['Class'])
print('\nThere are {} no fraud transactions: {:.4}%'.format(vc[0],(vc[0]/total)*100))
print('There are {} fraud transactions: {:.3}%\n'.format(vc[1],(vc[1]/total)*100))
# Out:
# There are 284315 no fraud transactions: 99.83%
# There are 492 fraud transactions: 0.173%

# %% [raw]
# There is heavy imbalance between the two classes. We have significantly less fraud transactions than legitimate. We should train our models with a balanced sub-dataset to ensure that the it can capture the nessesary patterns to recognize a fraud transction properly.

# %% [raw]
# Further data exploration like correlation matrix will be misleading due to heavy imbalance of the dataset.
#
# We have to extract a sub-dataset which is balanced (50-50) from fraud and no fraud classes.
#
# We will try to undersamble the majority class, oversample the minority class and combine both techniques for best results. We will investigate the best resampling practice

# %%
X = df.drop(['Class'],axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import recall_score, precision_score, confusion_matrix
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, classification_report

# Import classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

# %%
from imblearn.under_sampling import NearMiss, CondensedNearestNeighbour, TomekLinks, EditedNearestNeighbours
from imblearn.under_sampling import OneSidedSelection, NeighbourhoodCleaningRule, RandomUnderSampler
from imblearn.over_sampling import SVMSMOTE, KMeansSMOTE, SMOTE
from imblearn.combine import SMOTEENN, SMOTETomek

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=60)
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    190481
# 1       339
# Name: Class, dtype: int64

# %%
## Methods that choose examples to delete (should be combined with CNN to have a balanced dataset)

#undersampler = TomekLinks()
#undersampler = EditedNearestNeighbours()


## Methods that choose examples to keep
#undersampler = CondensedNearestNeighbour(n_jobs=-1)
#undersampler = NearMiss(version=3,n_neighbors=3)
#undersampler = RandomUnderSampler()

## Methods that both choose examples to keep or delete

# (combine CNN with ENN)
undersampler = NeighbourhoodCleaningRule(n_jobs=-1)

# (combine CNN with Tomek Links)
#undersampler = OneSidedSelection(n_neighbors = 1, n_seeds_S = 30,n_jobs=-1)


X_train_u, y_train_u = undersampler.fit_resample(X_train,y_train)
y_train_u.value_counts()
# Out:
# 0    190259
# 1       339
# Name: Class, dtype: int64

# %% [raw]
# ## Methods for oversampling
#
# #oversampler = SVMSMOTE(sampling_strategy=0.5, n_jobs=-1)
# #oversampler = SMOTE()
#
# X_train_o, y_train_o = oversampler.fit_resample(X_train,y_train)
# y_train_o.value_counts()

# %% [raw]
# # Methods for both under and over sampling
#
# resampler = SMOTETomek(sampling_strategy = 0.5, n_jobs=-1)
# #resampler = SMOTEENN(sampling_strategy= 0.1, n_jobs=-1)
#
# X_train_r, y_train_r = resampler.fit_resample(X_train,y_train)
# y_train_r.value_counts()

# %% [raw]
#  Classification models

# %%
def evaluate(clf):
    
    name = models[clf]
    clf.fit(train,labels)
    pred = clf.predict(X_test) 
    
    precision_list.append(precision_score(y_test, pred))
    recall_list.append(recall_score(y_test,pred))
    
    print('-'*55)
    print('\n' + name + ' Classifier\n')
    print('-'*55)
    
    #print('Precision: {}'.format(precision))
    #print('Recall: {}'.format(recall))
    
    print(classification_report(y_test,pred))
    
    cf = confusion_matrix(y_test, pred)
    print('True Positives: {}'.format(cf[1][1]))
    print('False Negatives: {}'.format(cf[1][0]))
    print('True Negatives: {}'.format(cf[0][0]))
    print('False Positives: {}'.format(cf[0][1]))
    
    fig, ax = plt.subplots(figsize=(7,5))

    plot_precision_recall_curve(clf,X_test,y_test,ax=ax)
    ax.set_title(name + ' Classifier Precision-Recall curve', fontsize=12)
    plt.show()
    print('\n\n')

# %%
models = {}
precision_list = []
recall_list = []

train = X_train_u
labels = y_train_u

lr = LogisticRegression(max_iter=1000)
models[lr] = 'Logistic Regression'

svm = SVC()
models[svm] = 'Support Vector'

knn = KNeighborsClassifier(n_neighbors=3,n_jobs=-1)
models[knn] = 'kNN'

xgb = XGBClassifier(use_label_encoder=False)
models[xgb] = 'XGBoost'

mlp = MLPClassifier(hidden_layer_sizes=(200,200),max_iter = 10000)
models[mlp] = 'MLP'

# %%
for model in models:
    evaluate(model)
# Out:
# -------------------------------------------------------
#
# Logistic Regression Classifier
#
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93834
#            1       0.79      0.77      0.78       153
#
#     accuracy                           1.00     93987
#    macro avg       0.89      0.89      0.89     93987
# weighted avg       1.00      1.00      1.00     93987
#
# True Positives: 118
# False Negatives: 35
# True Negatives: 93802
# False Positives: 32
# -------------------------------------------------------
#
# Support Vector Classifier
#
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93834
#            1       0.90      0.73      0.80       153
#
#     accuracy                           1.00     93987
# ...

# %%
fig, ax = plt.subplots(1,2,figsize=(20,8))

sns.barplot(list(models.values()),precision_list,ax=ax[0])
ax[0].set_title('Precision of Classifiers')
  

sns.barplot(list(models.values()),recall_list,ax=ax[1])
ax[1].set_title('Recall of Classifiers')

plt.show()

# %%
print(precision_list)
print(recall_list)
# Out:
# [0.7866666666666666, 0.8951612903225806, 0.8758620689655172, 0.875, 0.8486842105263158]
# [0.7712418300653595, 0.7254901960784313, 0.8300653594771242, 0.8235294117647058, 0.8431372549019608]

# %%
from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits=5,shuffle=True)#,random_state=20)

resampler_kf = SMOTE()


clf_kf = XGBClassifier(use_label_encoder=False)
#clf_kf = KNeighborsClassifier(n_neighbors=3,n_jobs=-1)

split_counter = 1
precisions_list = []
recalls_list = []

for train_index, test_index in kf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    #X_train, y_train = resampler_kf.fit_resample(X_train,y_train)
    
    clf_kf.fit(X_train,y_train)
    fold_pred = clf_kf.predict(X_test)
    fold_precision = precision_score(y_test, fold_pred)
    fold_recall = recall_score(y_test, fold_pred)
    precisions_list.append(fold_precision)
    recalls_list.append(fold_recall)
    
    print('\nFold {} Precision: {}  Recall: {}\n'.format(split_counter, fold_precision, fold_recall))
    split_counter = split_counter + 1

print('\n'+55*'-')   
print('Total performance for {}-Fold Cross Validation'.format(kf.get_n_splits()))
print('\nAverage precision: {}  Average Recall: {}\n'.format(np.mean(precisions_list),np.mean(recalls_list)))
# Out:
# [02:21:20] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\apost\anaconda3\lib\site-packages\xgboost\data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# Fold 1 Precision: 0.9647058823529412  Recall: 0.8282828282828283
#
# [02:21:34] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
